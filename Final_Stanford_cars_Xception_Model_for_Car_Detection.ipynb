# %% [markdown]
# <a href="https://colab.research.google.com/github/belanasaikiran/Team-6-Big-Data-Project/blob/main/Final_Stanford_cars_Xception_Model_for_Car_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Car Make & Model Detection:
# This project aims to detect the make and model of a given car.
# We use Stanford Car DataSet for training the model. We have over 196 classes in total for model detection.
#
# No. of claasses: 196
#
# We split the data using 60-40-40 rule
#
#
# Training Data:
#
# Validation Data:
#
# Test Data:
#
# **Team Members**:
#
# *   Ariannah Black
# *   Sai Kiran Belana
# *   Ummea Salma
# *   Md Ishtyaq Mahmud

# %% [markdown]
# The DataSet is structured in the following manner
#
# ```
# DataSet
# ├── data
# │   ├── meta.csv
# │   ├── test.csv
# │   └── train.csv
# └── images
#     ├── cars_test
#     └── cars_train
# ```

# %% [markdown]
# ## Todo:
# - [x] Import the DataSet.
# - [x] Preprocessing
# - [x] Feature Selection
# - [x] Model Selection
# - [x] Training the Model
# - [x] Test the Model

# %%
import tensorflow as tf
print("Tensorflow version " + tf.__version__)

# see the GPU in use
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# Tensorflow version 2.15.0
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 9499521861434330397
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15510929408
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 2464715945465475379
# physical_device_desc: "device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0"
# xla_global_id: 416903419
# ]

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
import warnings
import seaborn as sns
import matplotlib.pylab as plt
import PIL
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import f1_score
from keras import backend as K
from keras import layers, models, optimizers
from keras.preprocessing.image import ImageDataGenerator
from keras.applications import *
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

warnings.filterwarnings('ignore')
K.image_data_format()
# Out:
# 'channels_last'

# %%
BATCH_SIZE = 32
EPOCHS = 50
k_folds = 2
TTA_STEPS = 5
PATIENCE = 6
SEED = 2024
BASE_MODEL = Xception
IMAGE_SIZE = 299

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !unzip gdrive/MyDrive/Big\ Data\ Analytics\ Project\ \(Team\ 6\)/DataSet/DataSet.zip > /dev/null # output to null
# !unzip gdrive/MyDrive/BigDataAnalyticsProject/DataSet/DataSet.zip > /dev/null # output to null

# %% [markdown]
# Checking if image dataset is loaded

# %%
from PIL import Image

im = Image.open("/content/DataSet/images/cars_train/00001.jpg", "r")
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x400>

# %% [markdown]
# ## Load the Train & Test Datasets

# %%
DATA_PATH = '/content/DataSet/'
IMG_DATA_PATH = DATA_PATH + "images/"
CSV_DATA_PATH = DATA_PATH + "data/"

TRAIN_IMG_PATH = os.path.join(IMG_DATA_PATH, 'cars_train/')
TEST_IMG_PATH = os.path.join(IMG_DATA_PATH, 'cars_test/')

df_train = pd.read_csv(os.path.join(CSV_DATA_PATH, 'train.csv'))
df_test = pd.read_csv(os.path.join(CSV_DATA_PATH, 'test.csv'))
df_class = pd.read_csv(os.path.join(CSV_DATA_PATH, 'meta.csv'))

model_path = '/content/'

if not os.path.exists(model_path):
    os.mkdir(model_path)

# %%
def print_df(df, name):
    print(name + " Data:")
    print(df.info())
    print(df.shape)
    print("\n")

print_df(df_train, "Train")
print_df(df_test, "Test ")
print_df(df_class, "Class")
# Out:
# Train Data:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12948 entries, 0 to 12947
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  12948 non-null  int64
#  1   x1          12948 non-null  int64
#  2   y1          12948 non-null  int64
#  3   x2          12948 non-null  int64
#  4   y2          12948 non-null  int64
#  5   class       12948 non-null  int64
#  6   fname       12948 non-null  object
# dtypes: int64(6), object(1)
# memory usage: 708.2+ KB
# None
# (12948, 7)
#
#
# Test  Data:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3237 entries, 0 to 3236
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  3237 non-null   int64
#  1   x1          3237 non-null   int64
#  2   y1          3237 non-null   int64
#  3   x2          3237 non-null   int64
#  4   y2          3237 non-null   int64
#  5   class       3237 non-null   int64
#  6   fname       3237 non-null   object
# dtypes: int64(6), object(1)
# memory usage: 177.1+ KB
# None
# (3237, 7)
#
#
# Class Data:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196 entries, 0 to 195
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  196 non-null    int64
#  1   class_name  196 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 3.2+ KB
# None
# (196, 2)

# %% [markdown]
# Fixing the fname for one of the value in CSV

# %%
# fix the file names here
df_train.loc[9998, 'fname'] = '09999.jpg'

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Let's get an Average of images available per class
#
# We should get around 66 images per class with the `stanford car dataset`

# %%
counter = 0 #no. of images available per class in our dataset
average = 0 #average no. of images availabe for all our classes for training

for y in range(1, 197):
  for x in df_train['class']:
    if (x == y):
      # print("x, y", x, y)
      counter = counter+1;
  average = (average + counter)/y


print("Average:", average)
# Out:
# Average: 66.4000624886608

# %% [markdown]
# ### Helper Function: **Image Cropper**
#
# > Cropping the images using bounding boxes and separating the images into their respective folders accoringly.
#
#
#
# *   Read the dataset from CSV file
# *   Iterate over each image, resize it and its bounding box in CSV
# Crop the image using bounding box coordinates
# *   Save the cropped image

# %%
def image_box_cropper(img_name, path_images, data_frame, margin=0, size=(IMAGE_SIZE,IMAGE_SIZE)):
    PATH = path_images

    img = PIL.Image.open(os.path.join(PATH, img_name))
    # once we run below command, we delete the columns as well.
    pos = data_frame.loc[data_frame["fname"] == img_name, ['x1', 'y1', 'x2', 'y2']].values.reshape(-1)

    width, height = img.size
    x1 = max(0, pos[0] - margin)
    y1 = max(0, pos[1] - margin)
    x2 = min(pos[2] + margin, width)
    y2 = min(pos[3] + margin, height)

    croppedImage = img.crop((x1, y1, x2, y2)).resize(size)

    return croppedImage

# %%
# !rm -r /content/cropped_train/
# !rm -r /content/cropped_test/
# Out:
# rm: cannot remove '/content/cropped_train/': No such file or directory
# rm: cannot remove '/content/cropped_test/': No such file or directory

# %%
# %%time
TRAIN_CROPPED_PATH = '/content/cropped_train'
TEST_CROPPED_PATH = '/content/cropped_test'

if not os.path.isdir(TRAIN_CROPPED_PATH):
  os.mkdir(TRAIN_CROPPED_PATH)

if not os.path.isdir(TEST_CROPPED_PATH):
  os.mkdir(TEST_CROPPED_PATH)

for i, row in df_train.iterrows():
    cropped = image_box_cropper(row['fname'], TRAIN_IMG_PATH, df_train)
    cropped.save(os.path.join(TRAIN_CROPPED_PATH, row['fname']))

    if i == len(df_train) - 1:
      print("All Train Images have been cropped")

for i, row in df_test.iterrows():
    cropped = image_box_cropper(row['fname'], TEST_IMG_PATH, df_test)
    cropped.save(os.path.join(TEST_CROPPED_PATH, row['fname']))

    if i == len(df_test) - 1:
      print("All Test Images have been cropped")
# Out:
# All Train Images have been cropped
# All Test Images have been cropped
# CPU times: user 2min 31s, sys: 5.64 s, total: 2min 37s
# Wall time: 2min 36s

# %%
df_train['class'] = df_train['class'].astype('str')
df_train = df_train[['fname', 'class']]
df_test = df_test[['fname']]

# %% [markdown]
# ## Setting up our Helper Functions

# %%
def recall_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

def precision_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
def get_callback(model_name, patient):
    ES = EarlyStopping(
        monitor='val_f1_m',
        patience=patient,
        mode='max',
        verbose=1)
    RR = ReduceLROnPlateau(
        monitor = 'val_f1_m',
        factor = 0.5,
        patience = patient / 2,
        min_lr=0.000001,
        verbose=1,
        mode='max')
    MC = ModelCheckpoint(
        filepath=model_name,
        monitor='val_f1_m',
        verbose=1,
        save_best_only=True,
        mode='max')

    return [ES, RR, MC]

# %% [markdown]
# # Prepare the Data and Model for Machine Learning Algorithms
# ### Load the Xception Model

# %%
model_path = '/content/' #save model here

# %%
def get_model(model_name, image_size):
    base_model = model_name(weights='imagenet', input_shape=(image_size,image_size,3), include_top=False)
    #base_model.trainable = False
    model = models.Sequential()
    model.add(base_model)
    model.add(layers.GlobalAveragePooling2D())
    model.add(layers.Dense(2048, activation='relu', kernel_initializer='he_normal'))
    model.add(layers.Dropout(0.15))

    model.add(layers.Dense(196, activation='softmax', kernel_initializer='lecun_normal'))

    optimizer = optimizers.Nadam(learning_rate=0.0003)

    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['acc', f1_m, precision_m, recall_m])

    return model

# %%
model = get_model(BASE_MODEL, IMAGE_SIZE)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 3s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 10, 10, 2048)      20861480
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 2048)              4196352
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 196)               401604
#
# =================================================================
# Total params: 25459436 (97.12 MB)
# Trainable params: 25404908 (96.91 MB)
# Non-trainable params: 54528 (213.00 KB)
# _________________________________________________________________

# %% [markdown]
# ### Get Random Eraser:
# The function generates a new function, eraser, which when applied to an image, randomly obscures part of the image with a rectangle of random size, aspect ratio, and color.
#
#
# Source: https://github.com/yu4u/cutout-random-erasing

# %%
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %% [markdown]
# ## Data Augmentation (Highly Recommended):
#
# Create an ImageDataGenerator object to perform on-the-fly data augmentation during training, which helps prevent overfitting and improve model generalization perform Data Augmentation
#
# Since the dataset is limited, augmenting our data artificially increases the diversity of our training data.

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    #featurewise_center= True,  # set input mean to 0 over the dataset
    #samplewise_center=True,  # set each sample mean to 0
    #featurewise_std_normalization= True,  # divide inputs by std of the dataset
    #samplewise_std_normalization=True,  # divide each input by its std
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=False,
    zoom_range=0.3,
    shear_range=0.5,
    brightness_range=[0.5, 1.5],
    fill_mode='nearest',
    preprocessing_function = get_random_eraser(v_l=0, v_h=255),
    )

valid_datagen = ImageDataGenerator(
    rescale=1./255,
    #featurewise_center= True,  # set input mean to 0 over the dataset
    #samplewise_center=True,  # set each sample mean to 0
    #featurewise_std_normalization= True,  # divide inputs by std of the dataset
    #samplewise_std_normalization=True  # divide each input by its std
    )
test_datagen = ImageDataGenerator(
    rescale=1./255,
    #featurewise_center= True,  # set input mean to 0 over the dataset
    #samplewise_center=True,  # set each sample mean to 0
    #featurewise_std_normalization= True,  # divide inputs by std of the dataset
    #samplewise_std_normalization=True,  # divide each input by its std
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=False,
    zoom_range=0.3,
    shear_range=0.5,
    brightness_range=[0.5, 1.5],
    fill_mode='nearest',
    preprocessing_function = get_random_eraser(v_l=0, v_h=255),
    )

# %% [markdown]
# ### Plotting some augumented training images
#
# Displaying some randomly augmented training images

# %%
import matplotlib.pyplot as plt

datagen = ImageDataGenerator(rotation_range=90)

# Generate 10 augmented images from a single input image
x = np.expand_dims(plt.imread("/content/cropped_train/00001.jpg"), 0)
gen = datagen.flow(x, batch_size=1)

for i in range(10):
    plt.subplot(2, 5, i+1)
    plt.imshow(gen.next()[0].astype('uint8'))
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Using StratifiedKFold
#
# > Stratified K-Fold Cross-Validation is a variation of K-Fold Cross-Validation that ensures each fold maintains the same proportion of observations for each target class as the complete dataset.
#
# >  It ensures the training and test sets have the same proportion of the feature of interest as in the original dataset. Doing this with the target variable ensures that the cross-validation result is a close approximation of generalization error.

# %%
# skf = StratifiedKFold(n_splits=k_folds)
skf = KFold(n_splits=k_folds)

# %% [markdown]
# save model history for plotting

# %%
history_list = []

# %%
# %%time
j = 1
model_names = []
for (train_index, valid_index) in skf.split(
    df_train['fname'],
    df_train['class']):


    traindf = df_train
    validdf = df_train.iloc[valid_index, :].reset_index()

    print("=========================================")
    print("====== K Fold Validation step => %d/%d =======" % (j,k_folds))
    print("=========================================")

    train_generator = train_datagen.flow_from_dataframe(
        dataframe=traindf,
        directory=TRAIN_CROPPED_PATH,
        x_col='fname',
        y_col='class',
        target_size= (IMAGE_SIZE, IMAGE_SIZE),
        color_mode='rgb',
        class_mode='categorical',
        batch_size=BATCH_SIZE,
        seed=SEED,
        shuffle=True
        )

    valid_generator = valid_datagen.flow_from_dataframe(
        dataframe=validdf,
        directory=TRAIN_CROPPED_PATH,
        x_col='fname',
        y_col='class',
        target_size= (IMAGE_SIZE, IMAGE_SIZE),
        color_mode='rgb',
        class_mode='categorical',
        batch_size=BATCH_SIZE,
        seed=SEED,
        shuffle=True
        )

    model_name = model_path + str(j) + '_' + 'Xception-Model' + '.hdf5'
    model_names.append(model_name)

    model = get_model(BASE_MODEL, IMAGE_SIZE)

    try:
        model.load_weights(model_name)
    except:
        pass

    history = model.fit_generator(
        train_generator,
        steps_per_epoch=len(traindf.index) / BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=valid_generator,
        validation_steps=len(validdf.index) / BATCH_SIZE,
        verbose=1,
        shuffle=False,
        callbacks = get_callback(model_name, PATIENCE)
        )
    history_list.append(history)

    j+=1
# Out:
# =========================================
# ====== K Fold Validation step => 1/2 =======
# =========================================
# Found 12948 validated image filenames belonging to 196 classes.
# Found 6474 validated image filenames belonging to 196 classes.
# Epoch 1/50
# 405/404 [==============================] - ETA: 0s - loss: 3.1860 - acc: 0.2800 - f1_m: 0.1906 - precision_m: 0.4898 - recall_m: 0.1273
# Epoch 1: val_f1_m improved from -inf to 0.66951, saving model to /content/1_Xception-Model.hdf5
# 404/404 [==============================] - 368s 827ms/step - loss: 3.1860 - acc: 0.2800 - f1_m: 0.1906 - precision_m: 0.4898 - recall_m: 0.1273 - val_loss: 1.1036 - val_acc: 0.6636 - val_f1_m: 0.6695 - val_precision_m: 0.7811 - val_recall_m: 0.5885 - lr: 3.0000e-04
# Epoch 2/50
# 405/404 [==============================] - ETA: 0s - loss: 1.0874 - acc: 0.6855 - f1_m: 0.6684 - precision_m: 0.8366 - recall_m: 0.5612
# Epoch 2: val_f1_m improved from 0.66951 to 0.83822, saving model to /content/1_Xception-Model.hdf5
# 404/404 [==============================] - 323s 798ms/step - loss: 1.0874 - acc: 0.6855 - f1_m: 0.6684 - precision_m: 0.8366 - recall_m: 0.5612 - val_loss: 0.5226 - val_acc: 0.8350 - val_f1_m: 0.8382 - val_precision_m: 0.8895 - val_recall_m: 0.7938 - lr: 3.0000e-04
# Epoch 3/50
# 405/404 [==============================] - ETA: 0s - loss: 0.6671 - acc: 0.8000 - f1_m: 0.7985 - precision_m: 0.8832 - recall_m: 0.7311
# Epoch 3: val_f1_m improved from 0.83822 to 0.89485, saving model to /content/1_Xception-Model.hdf5
# 404/404 [==============================] - 329s 812ms/step - loss: 0.6671 - acc: 0.8000 - f1_m: 0.7985 - precision_m: 0.8832 - recall_m: 0.7311 - val_loss: 0.3092 - val_acc: 0.8923 - val_f1_m: 0.8949 - val_precision_m: 0.9222 - val_recall_m: 0.8699 - lr: 3.0000e-04
# Epoch 4/50
# 405/404 [==============================] - ETA: 0s - loss: 0.5178 - acc: 0.8394 - f1_m: 0.8420 - precision_m: 0.8993 - recall_m: 0.7931
# Epoch 4: val_f1_m improved from 0.89485 to 0.94228, saving model to /content/1_Xception-Model.hdf5
# 404/404 [==============================] -
50
# 405/404 [==============================] - ETA: 0s - loss: 0.0440 - acc: 0.9848 - f1_m: 0.9852 - precision_m: 0.9872 - recall_m: 0.9832
# Epoch 31: val_f1_m did not improve from 0.99661
# 404/404 [==============================] - 321s 793ms/step - loss: 0.0440 - acc: 0.9848 - f1_m: 0.9852 - precision_m: 0.9872 - recall_m: 0.9832 - val_loss: 0.0085 - val_acc: 0.9966 - val_f1_m: 0.9966 - val_precision_m: 0.9966 - val_recall_m: 0.9966 - lr: 3.7500e-05
# Epoch 32/50
# 405/404 [==============================] - ETA: 0s - loss: 0.0391 - acc: 0.9857 - f1_m: 0.9860 - precision_m: 0.9885 - recall_m: 0.9836
# Epoch 32: val_f1_m did not improve from 0.99661
# 404/404 [==============================] - 321s 794ms/step - loss: 0.0391 - acc: 0.9857 - f1_m: 0.9860 - precision_m: 0.9885 - recall_m: 0.9836 - val_loss: 0.0085 - val_acc: 0.9961 - val_f1_m: 0.9961 - val_precision_m: 0.9963 - val_recall_m: 0.9960 - lr: 3.7500e-05
# Epoch 33/50
# 405/404 [==============================] - ETA: 0s - loss: 0.0443 - acc: 0.9839 - f1_m: 0.9843 - precision_m: 0.9864 - recall_m: 0.9823
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1.8750000890577212e-05.
#
# Epoch 33: val_f1_m did not improve from 0.99661
# 404/404 [==============================] - 326s 805ms/step - loss: 0.0443 - acc: 0.9839 - f1_m: 0.9843 - precision_m: 0.9864 - recall_m: 0.9823 - val_loss: 0.0090 - val_acc: 0.9958 - val_f1_m: 0.9958 - val_precision_m: 0.9958 - val_recall_m: 0.9958 - lr: 3.7500e-05
# Epoch 34/50
# 405/404 [==============================] - ETA: 0s - loss: 0.0389 - acc: 0.9876 - f1_m: 0.9880 - precision_m: 0.9902 - recall_m: 0.9860
# Epoch 34: val_f1_m did not improve from 0.99661
# 404/404 [==============================] - 330s 816ms/step - loss: 0.0389 - acc: 0.9876 - f1_m: 0.9880 - precision_m: 0.9902 - recall_m: 0.9860 - val_loss: 0.0074 - val_acc: 0.9961 - val_f1_m: 0.9962 - val_precision_m: 0.9962 - val_recall_m: 0.9962 - lr: 1.8750e-05
# Epoch 35/50
# 405/404 [==============================] - ETA: 0s - loss: 0.0391 - acc: 0.9868 - f1_m: 0.9869 - precision_m: 0.9891 - recall_m: 0.9849
# Epoch 35: val_f1_m did not improve from 0.99661
# 404/404 [==============================] - 327s 808ms/step - loss: 0.0391 - acc: 0.9868 - f1_m: 0.9869 - precision_m: 0.9891 - recall_m: 0.9849 - val_loss: 0.0071 - val_acc: 0.9963 - val_f1_m: 0.9963 - val_precision_m: 0.9963 - val_recall_m: 0.9963 - lr: 1.8750e-05
# Epoch 36/50
# 405/404 [==============================] - ETA: 0s - loss: 0.0340 - acc: 0.9883 - f1_m: 0.9884 - precision_m: 0.9901 - recall_m: 0.9867
# Epoch 36: ReduceLROnPlateau reducing learning rate to 9.375000445288606e-06.
#
# Epoch 36: val_f1_m did not improve from 0.99661
# 404/404 [==============================] - 325s 804ms/step - loss: 0.0340 - acc: 0.9883 - f1_m: 0.9884 - precision_m: 0.9901 - recall_m: 0.9867 - val_loss: 0.0071 - val_acc: 0.9966 - val_f1_m: 0.9966 - val_precision_m: 0.9966 - val_recall_m: 0.9966 - lr: 1.8750e-05
# Epoch 36: early stopping
# =========================================
# ====== K Fold Validation step => 2/2 =======
# =========================================
# Found 12948 validated image filenames belonging to 196 classes.
# Found 6474 validated image filenames belonging to 196 classes.
# Epoch 1/50
# 405/404 [==============================] - ETA: 0s - loss: 3.1426 - acc: 0.2822 - f1_m: 0.1896 - precision_m: 0.5043 - recall_m: 0.1269
# Epoch 1: val_f1_m improved from -inf to 0.68177, saving model to /content/2_Xception-Model.hdf5
# 404/404 [==============================] -
saving model to /content/2_Xception-Model.hdf5
# 404/404 [==============================] - 327s 809ms/step - loss: 0.3498 - acc: 0.8906 - f1_m: 0.8929 - precision_m: 0.9246 - recall_m: 0.8642 - val_loss: 0.1065 - val_acc: 0.9629 - val_f1_m: 0.9616 - val_precision_m: 0.9681 - val_recall_m: 0.9554 - lr: 3.0000e-04
# Epoch 8/50
# 405/404 [==============================] - ETA: 0s - loss: 0.3287 - acc: 0.8958 - f1_m: 0.8983 - precision_m: 0.9284 - recall_m: 0.8710
# Epoch 8: val_f1_m did not improve from 0.96159
# 404/404 [==============================] - 327s 807ms/step - loss: 0.3287 - acc: 0.8958 - f1_m: 0.8983 - precision_m: 0.9284 - recall_m: 0.8710 - val_loss: 0.1585 - val_acc: 0.9490 - val_f1_m: 0.9493 - val_precision_m: 0.9547 - val_recall_m: 0.9441 - lr: 3.0000e-04
# Epoch 9/50
# 405/404 [==============================] - ETA: 0s - loss: 0.2871 - acc: 0.9094 - f1_m: 0.9110 - precision_m: 0.9369 - recall_m: 0.8873
# Epoch 9: val_f1_m improved from 0.96159 to 0.97109, saving model to /content/2_Xception-Model.hdf5
# 404/404 [==============================] - 326s 805ms/step - loss: 0.2871 - acc: 0.9094 - f1_m: 0.9110 - precision_m: 0.9369 - recall_m: 0.8873 - val_loss: 0.0813 - val_acc: 0.9710 - val_f1_m: 0.9711 - val_precision_m: 0.9737 - val_recall_m: 0.9686 - lr: 3.0000e-04
# Epoch 10/50
# 405/404 [==============================] - ETA: 0s - loss: 0.2816 - acc: 0.9108 - f1_m: 0.9127 - precision_m: 0.9363 - recall_m: 0.8909
# Epoch 10: val_f1_m did not improve from 0.97109
# 404/404 [==============================] - 317s 784ms/step - loss: 0.2816 - acc: 0.9108 - f1_m: 0.9127 - precision_m: 0.9363 - recall_m: 0.8909 - val_loss: 0.1382 - val_acc: 0.9547 - val_f1_m: 0.9546 - val_precision_m: 0.9585 - val_recall_m: 0.9509 - lr: 3.0000e-04
# Epoch 11/50
# 405/404 [==============================] - ETA: 0s - loss: 0.2586 - acc: 0.9209 - f1_m: 0.9210 - precision_m: 0.9416 - recall_m: 0.9018
# Epoch 11: val_f1_m improved from 0.97109 to 0.97243, saving model to /content/2_Xception-Model.hdf5
# 404/404 [==============================] - 323s 798ms/step - loss: 0.2586 - acc: 0.9209 - f1_m: 0.9210 - precision_m: 0.9416 - recall_m: 0.9018 - val_loss: 0.0856 - val_acc: 0.9717 - val_f1_m: 0.9724 - val_precision_m: 0.9748 - val_recall_m: 0.9701 - lr: 3.0000e-04
# Epoch 12/50
# 405/404 [==============================] - ETA: 0s - loss: 0.2492 - acc: 0.9228 - f1_m: 0.9225 - precision_m: 0.9436 - recall_m: 0.9030
# Epoch 12: val_f1_m did not improve from 0.97243
# 404/404 [==============================] - 322s 795ms/step - loss: 0.2492 - acc: 0.9228 - f1_m: 0.9225 - precision_m: 0.9436 - recall_m: 0.9030 - val_loss: 0.1128 - val_acc: 0.9605 - val_f1_m: 0.9609 - val_precision_m: 0.9634 - val_recall_m: 0.9584 - lr: 3.0000e-04
# Epoch 13/50
# 405/404 [==============================] - ETA: 0s - loss: 0.2337 - acc: 0.9303 - f1_m: 0.9313 - precision_m: 0.9488 - recall_m: 0.9150
# Epoch 13: val_f1_m improved from 0.97243 to 0.97405, saving model to /content/2_Xception-Model.hdf5
# 404/404 [==============================] - 317s 782ms/step - loss: 0.2337 - acc: 0.9303 - f1_m: 0.9313 - precision_m: 0.9488 - recall_m: 0.9150 - val_loss: 0.0738 - val_acc: 0.9744 - val_f1_m: 0.9740 - val_precision_m: 0.9762 - val_recall_m: 0.9720 - lr: 3.0000e-04
# Epoch 14/50
# 405/404 [==============================] - ETA: 0s - loss: 0.2319 - acc: 0.9269 - f1_m: 0.9289 - precision_m: 0.9483 - recall_m: 0.9108
# Epoch 14: val_f1_m improved from 0.97405 to 0.97524, saving model to /content/2_Xception-Model.hdf5
# 404/404 [==============================] - 322s 796ms/step - loss: 0.2319 - acc: 0.9269 - f1_m: 0.9289 - precision_m: 0.9483 - recall_m: 0.9108 - val_loss: 0.0803 - val_acc: 0.9750 - val_f1_m: 0.9752 - val_precision_m: 0.9784 - val_recall_m: 0.9723 - lr: 3.0000e-04
# Epoch 15/50
# 405/404 [==============================] - ETA: 0s - loss: 0.2230 - acc: 0.9313 - f1_m: 0.9332 - precision_m: 0.9505 - recall_m: 0.9171
# Epoch 15: val_f1_m did not improve from 0.97524
# 404/404 [==============================] - 323s 798ms/step - loss: 0.2230 - acc: 0.9313 - f1_m: 0.9332 - precision_m: 0.9505 - recall_m: 0.9171 - val_loss: 0.0748 - val_acc: 0.9731 - val_f1_m: 0.9728 - val_precision_m: 0.9752 - val_recall_m: 0.9704 - lr: 3.0000e-04
# Epoch 16/50
# 405/404 [==============================] - ETA: 0s - loss: 0.2110 - acc: 0.9333 - f1_m: 0.9350 - precision_m: 0.9517 - recall_m: 0.9194
# Epoch 16: val_f1_m improved from 0.97524 to 0.98164, saving model to /content/2_Xception-Model.hdf5
# 404/404 [==============================] - 327s 807ms/step - loss: 0.2110 - acc: 0.9333 - f1_m: 0.9350 - precision_m: 0.9517 - recall_m: 0.9194 - val_loss: 0.0577 - val_acc: 0.9818 - val_f1_m: 0.9816 - val_precision_m: 0.9827 - val_recall_m: 0.9806 - lr: 3.0000e-04
# Epoch 17/50
# 405/404 [==============================] - ETA: 0s - loss: 0.2114 - acc: 0.9353 - f1_m: 0.9357 - precision_m: 0.9525 - recall_m: 0.9200
# Epoch 17: val_f1_m did not improve from 0.98164
# 404/404 [==============================] - 326s 806ms/step - loss: 0.2114 - acc: 0.9353 - f1_m: 0.9357 - precision_m: 0.9525 - recall_m: 0.9200 - val_loss: 0.0522 - val_acc: 0.9805 - val_f1_m: 0.9807 - val_precision_m: 0.9820 - val_recall_m: 0.9795 - lr: 3.0000e-04
# Epoch 18/50
# 405/404 [==============================] - ETA: 0s - loss: 0.1948 - acc: 0.9414 - f1_m: 0.9418 - precision_m: 0.9582 - recall_m: 0.9265
# Epoch 18: val_f1_m did not improve from 0.98164
# 404/404 [==============================] - 329s 812ms/step - loss: 0.1948 - acc: 0.9414 - f1_m: 0.9418 - precision_m: 0.9582 - recall_m: 0.9265 - val_loss: 0.0785 - val_acc: 0.9747 - val_f1_m: 0.9754 - val_precision_m: 0.9772 - val_recall_m: 0.9737 - lr: 3.0000e-04
# Epoch 19/50
# 405/404 [==============================] - ETA: 0s - loss: 0.1952 - acc: 0.9398 - f1_m: 0.9416 - precision_m: 0.9562 - recall_m: 0.9278
# Epoch 19: val_f1_m improved from 0.98164 to 0.98262, saving model to /content/2_Xception-Model.hdf5
# 404/404 [==============================] - 331s 818ms/step - loss: 0.1952 - acc: 0.9398 - f1_m: 0.9416 - precision_m: 0.9562 - recall_m: 0.9278 - val_loss: 0.0544 - val_acc: 0.9830 - val_f1_m: 0.9826 - val_precision_m: 0.9844 - val_recall_m: 0.9809 - lr: 3.0000e-04
# Epoch 20/50
# 405/404 [==============================] - ETA: 0s - loss: 0.1885 - acc: 0.9404 - f1_m: 0.9420 - precision_m: 0.9550 - recall_m: 0.9298
# Epoch 20: val_f1_m did not improve from 0.98262
# 404/404 [==============================] - 328s 811ms/step - loss: 0.1885 - acc: 0.9404 - f1_m: 0.9420 - precision_m: 0.9550 - recall_m: 0.9298 - val_loss: 0.1374 - val_acc: 0.9554 - val_f1_m: 0.9552 - val_precision_m: 0.9579 - val_recall_m: 0.9526 - lr: 3.0000e-04
# Epoch 21/50
# 405/404 [==============================] - ETA: 0s - loss: 0.1862 - acc: 0.9426 - f1_m: 0.9438 - precision_m: 0.9584 - recall_m: 0.9301
# Epoch 21: val_f1_m improved from 0.98262 to 0.98281, saving model to /content/2_Xception-Model.hdf5
# 404/404 [==============================] - 330s 816ms/step - loss: 0.1862 - acc: 0.9426 - f1_m: 0.9438 - precision_m: 0.9584 - recall_m: 0.9301 - val_loss: 0.0490 - val_acc: 0.9830 - val_f1_m: 0.9828 - val_precision_m: 0.9837 - val_recall_m: 0.9820 - lr: 3.0000e-04
# Epoch 22/50
# 405/404 [==============================] - ETA: 0s - loss: 0.1882 - acc: 0.9417 - f1_m: 0.9433 - precision_m: 0.9567 - recall_m: 0.9306
# Epoch 22: val_f1_m did not improve from 0.98281
# 404/404 [==============================] - 332s 820ms/step - loss: 0.1882 - acc: 0.9417 - f1_m: 0.9433 - precision_m: 0.9567 - recall_m: 0.9306 - val_loss: 0.0669 - val_acc: 0.9785 - val_f1_m: 0.9782 - val_precision_m: 0.9799 - val_recall_m: 0.9766 - lr: 3.0000e-04
# Epoch 23/50
# 405/404 [==============================] - ETA: 0s - loss: 0.1674 - acc: 0.9473 - f1_m: 0.9479 - precision_m: 0.9606 - recall_m: 0.9358
# Epoch 23: val_f1_m did not improve from 0.98281
# 404/404 [==============================] - 330s 814ms/step - loss: 0.1674 - acc: 0.9473 - f1_m: 0.9479 - precision_m: 0.9606 - recall_m: 0.9358 - val_loss: 0.0802 - val_acc: 0.9737 - val_f1_m: 0.9738 - val_precision_m: 0.9761 - val_recall_m: 0.9715 - lr: 3.0000e-04
# Epoch 24/50
# 405/404 [==============================] - ETA: 0s - loss: 0.1583 - acc: 0.9498 - f1_m: 0.9512 - precision_m: 0.9628 - recall_m: 0.9403
# Epoch 24: val_f1_m improved from 0.98281 to 0.98482, saving model to /content/2_Xception-Model.hdf5
# 404/404 [==============================] - 331s 817ms/step - loss: 0.1583 - acc: 0.9498 - f1_m: 0.9512 - precision_m: 0.9628 - recall_m: 0.9403 - val_loss: 0.0435 - val_acc: 0.9849 - val_f1_m: 0.9848 - val_precision_m: 0.9852 - val_recall_m: 0.9845 - lr: 3.0000e-04
# Epoch 25/50
# 405/404 [==============================] - ETA: 0s - loss: 0.1812 - acc: 0.9414 - f1_m: 0.9437 - precision_m: 0.9570 - recall_m: 0.9311
# Epoch 25: val_f1_m improved from 0.98482 to 0.98543, saving model to /content/2_Xception-Model.hdf5
# 404/404 [==============================] - 330s 814ms/step - loss: 0.1812 - acc: 0.9414 - f1_m: 0.9437 - precision_m: 0.9570 - recall_m: 0.9311 - val_loss: 0.0565 - val_acc: 0.9853 - val_f1_m: 0.9854 - val_precision_m: 0.9858 - val_recall_m: 0.9851 - lr: 3.0000e-04
# Epoch 26/50
# 405/404 [==============================] - ETA: 0s - loss: 0.1540 - acc: 0.9510 - f1_m: 0.9524 - precision_m: 0.9638 - recall_m: 0.9416
# Epoch 26: val_f1_m improved from 0.98543 to 0.98550, saving model to /content/2_Xception-Model.hdf5
# 404/404 [==============================] - 331s 817ms/step - loss: 0.1540 - acc: 0.9510 - f1_m: 0.9524 - precision_m: 0.9638 - recall_m: 0.9416 - val_loss: 0.0426 - val_acc: 0.9861 - val_f1_m: 0.9855 - val_precision_m: 0.9866 - val_recall_m: 0.9845 - lr: 3.0000e-04
# Epoch 27/50
# 405/404 [==============================] - ETA: 0s - loss: 0.1584 - acc: 0.9495 - f1_m: 0.9493 - precision_m: 0.9604 - recall_m: 0.9388
# Epoch 27: val_f1_m did not improve from 0.98550
# 404/404 [==============================] - 329s 812ms/step - loss: 0.1584 - acc: 0.9495 - f1_m: 0.9493 - precision_m: 0.9604 - recall_m: 0.9388 - val_loss: 0.0480 - val_acc: 0.9841 - val_f1_m: 0.9842 - val_precision_m: 0.9849 - val_recall_m: 0.9835 - lr: 3.0000e-04
# Epoch 28/50
# 405/404 [==============================] - ETA: 0s - loss: 0.1439 - acc: 0.9555 - f1_m: 0.9559 - precision_m: 0.9649 - recall_m: 0.9473
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
#
# Epoch 28: val_f1_m improved from 0.98550 to 0.98552, saving model to /content/2_Xception-Model.hdf5
# 404/404 [==============================] - 333s 821ms/step - loss: 0.1439 - acc: 0.9555 - f1_m: 0.9559 - precision_m: 0.9649 - recall_m: 0.9473 - val_loss: 0.0393 - val_acc: 0.9852 - val_f1_m: 0.9855 - val_precision_m: 0.9858 - val_recall_m: 0.9852 - lr: 3.0000e-04
# Epoch 29/50
# 405/404 [==============================] - ETA: 0s - loss: 0.1044 - acc: 0.9671 - f1_m: 0.9674 - precision_m: 0.9744 - recall_m: 0.9608
# Epoch 29: val_f1_m improved from 0.98552 to 0.99484, saving model to /content/2_Xception-Model.hdf5
# 404/404 [==============================] - 331s 817ms/step - loss: 0.1044 - acc: 0.9671 - f1_m: 0.9674 - precision_m: 0.9744 - recall_m: 0.9608 - val_loss: 0.0130 - val_acc: 0.9947 - val_f1_m: 0.9948 - val_precision_m: 0.9949 - val_recall_m: 0.9948 - lr: 1.5000e-04
# Epoch 30/50
# 405/404 [==============================] - ETA: 0s - loss: 0.0818 - acc: 0.9758 - f1_m: 0.9757 - precision_m: 0.9809 - recall_m: 0.9708
# Epoch 30: val_f1_m did not improve from 0.99484
# 404/404 [==============================] - 331s 818ms/step - loss: 0.0818 - acc: 0.9758 - f1_m: 0.9757 - precision_m: 0.9809 - recall_m: 0.9708 - val_loss: 0.0134 - val_acc: 0.9949 - val_f1_m: 0.9948 - val_precision_m: 0.9949 - val_recall_m: 0.9948 - lr: 1.5000e-04
# Epoch 31/50
# 405/404 [==============================] - ETA: 0s - loss: 0.0683 - acc: 0.9763 - f1_m: 0.9766 - precision_m: 0.9806 - recall_m: 0.9727
# Epoch 31: val_f1_m improved from 0.99484 to 0.99592, saving model to /content/2_Xception-Model.hdf5
# 404/404 [==============================] - 332s 821ms/step - loss: 0.0683 - acc: 0.9763 - f1_m: 0.9766 - precision_m: 0.9806 - recall_m: 0.9727 - val_loss: 0.0121 - val_acc: 0.9958 - val_f1_m: 0.9959 - val_precision_m: 0.9960 - val_recall_m: 0.9958 - lr: 1.5000e-04
# Epoch 32/50
# 405/404 [==============================] - ETA: 0s - loss: 0.0760 - acc: 0.9740 - f1_m: 0.9757 - precision_m: 0.9805 - recall_m: 0.9711
# Epoch 32: val_f1_m did not improve from 0.99592
# 404/404 [==============================] - 329s 813ms/step - loss: 0.0760 - acc: 0.9740 - f1_m: 0.9757 - precision_m: 0.9805 - recall_m: 0.9711 - val_loss: 0.0173 - val_acc: 0.9927 - val_f1_m: 0.9927 - val_precision_m: 0.9928 - val_recall_m: 0.9926 - lr: 1.5000e-04
# Epoch 33/50
# 405/404 [==============================] - ETA: 0s - loss: 0.0762 - acc: 0.9763 - f1_m: 0.9763 - precision_m: 0.9806 - recall_m: 0.9722
# Epoch 33: val_f1_m did not improve from 0.99592
# 404/404 [==============================] - 331s 818ms/step - loss: 0.0762 - acc: 0.9763 - f1_m: 0.9763 - precision_m: 0.9806 - recall_m: 0.9722 - val_loss: 0.0184 - val_acc: 0.9918 - val_f1_m: 0.9919 - val_precision_m: 0.9920 - val_recall_m: 0.9918 - lr: 1.5000e-04
# Epoch 34/50
# 405/404 [==============================] - ETA: 0s - loss: 0.0746 - acc: 0.9754 - f1_m: 0.9757 - precision_m: 0.9807 - recall_m: 0.9709
# Epoch 34: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
#
# Epoch 34: val_f1_m did not improve from 0.99592
# 404/404 [==============================] - 332s 821ms/step - loss: 0.0746 - acc: 0.9754 - f1_m: 0.9757 - precision_m: 0.9807 - recall_m: 0.9709 - val_loss: 0.0119 - val_acc: 0.9958 - val_f1_m: 0.9959 - val_precision_m: 0.9960 - val_recall_m: 0.9958 - lr: 1.5000e-04
# Epoch 35/50
# 405/404 [==============================] - ETA: 0s - loss: 0.0555 - acc: 0.9817 - f1_m: 0.9822 - precision_m: 0.9862 - recall_m: 0.9782
# Epoch 35: val_f1_m improved from 0.99592 to 0.99708, saving model to /content/2_Xception-Model.hdf5
# 404/404 [==============================] - 332s 821ms/step - loss: 0.0555 - acc: 0.9817 - f1_m: 0.9822 - precision_m: 0.9862 - recall_m: 0.9782 - val_loss: 0.0084 - val_acc: 0.9971 - val_f1_m: 0.9971 - val_precision_m: 0.9971 - val_recall_m: 0.9971 - lr: 7.5000e-05
# Epoch 36/50
# 405/404 [==============================] - ETA: 0s - loss: 0.0502 - acc: 0.9843 - f1_m: 0.9851 - precision_m: 0.9881 - recall_m: 0.9822
# Epoch 36: val_f1_m did not improve from 0.99708
# 404/404 [==============================] - 332s 821ms/step - loss: 0.0502 - acc: 0.9843 - f1_m: 0.9851 - precision_m: 0.9881 - recall_m: 0.9822 - val_loss: 0.0069 - val_acc: 0.9968 - val_f1_m: 0.9968 - val_precision_m: 0.9969 - val_recall_m: 0.9966 - lr: 7.5000e-05
# Epoch 37/50
# 405/404 [==============================] - ETA: 0s - loss: 0.0488 - acc: 0.9838 - f1_m: 0.9846 - precision_m: 0.9871 - recall_m: 0.9821
# Epoch 37: val_f1_m improved from 0.99708 to 0.99738, saving model to /content/2_Xception-Model.hdf5
# 404/404 [==============================] - 335s 828ms/step - loss: 0.0488 - acc: 0.9838 - f1_m: 0.9846 - precision_m: 0.9871 - recall_m: 0.9821 - val_loss: 0.0067 - val_acc: 0.9974 - val_f1_m: 0.9974 - val_precision_m: 0.9974 - val_recall_m: 0.9974 - lr: 7.5000e-05
# Epoch 38/50
# 405/404 [==============================] - ETA: 0s - loss: 0.0435 - acc: 0.9848 - f1_m: 0.9853 - precision_m: 0.9879 - recall_m: 0.9827
# Epoch 38: val_f1_m did not improve from 0.99738
# 404/404 [==============================] - 330s 814ms/step - loss: 0.0435 - acc: 0.9848 - f1_m: 0.9853 - precision_m: 0.9879 - recall_m: 0.9827 - val_loss: 0.0075 - val_acc: 0.9968 - val_f1_m: 0.9968 - val_precision_m: 0.9968 - val_recall_m: 0.9968 - lr: 7.5000e-05
# Epoch 39/50
# 405/404 [==============================] - ETA: 0s - loss: 0.0460 - acc: 0.9841 - f1_m: 0.9848 - precision_m: 0.9872 - recall_m: 0.9824
# Epoch 39: val_f1_m did not improve from 0.99738
# 404/404 [==============================] - 330s 815ms/step - loss: 0.0460 - acc: 0.9841 - f1_m: 0.9848 - precision_m: 0.9872 - recall_m: 0.9824 - val_loss: 0.0074 - val_acc: 0.9966 - val_f1_m: 0.9967 - val_precision_m: 0.9968 - val_recall_m: 0.9966 - lr: 7.5000e-05
# Epoch 40/50
# 405/404 [==============================] - ETA: 0s - loss: 0.0431 - acc: 0.9853 - f1_m: 0.9859 - precision_m: 0.9884 - recall_m: 0.9834
# Epoch 40: ReduceLROnPlateau reducing learning rate to 3.7500001781154424e-05.
#
# Epoch 40: val_f1_m did not improve from 0.99738
# 404/404 [==============================] - 327s 808ms/step - loss: 0.0431 - acc: 0.9853 - f1_m: 0.9859 - precision_m: 0.9884 - recall_m: 0.9834 - val_loss: 0.0074 - val_acc: 0.9971 - val_f1_m: 0.9971 - val_precision_m: 0.9972 - val_recall_m: 0.9971 - lr: 7.5000e-05
# Epoch 41/50
# 405/404 [==============================] - ETA: 0s - loss: 0.0355 - acc: 0.9877 - f1_m: 0.9877 - precision_m: 0.9896 - recall_m: 0.9858
# Epoch 41: val_f1_m did not improve from 0.99738
# 404/404 [==============================] - 327s 808ms/step - loss: 0.0355 - acc: 0.9877 - f1_m: 0.9877 - precision_m: 0.9896 - recall_m: 0.9858 - val_loss: 0.0064 - val_acc: 0.9964 - val_f1_m: 0.9965 - val_precision_m: 0.9968 - val_recall_m: 0.9963 - lr: 3.7500e-05
# Epoch 42/50
# 405/404 [==============================] - ETA: 0s - loss: 0.0329 - acc: 0.9880 - f1_m: 0.9876 - precision_m: 0.9893 - recall_m: 0.9860
# Epoch 42: val_f1_m did not improve from 0.99738
# 404/404 [==============================] - 333s 822ms/step - loss: 0.0329 - acc: 0.9880 - f1_m: 0.9876 - precision_m: 0.9893 - recall_m: 0.9860 - val_loss: 0.0065 - val_acc: 0.9971 - val_f1_m: 0.9971 - val_precision_m: 0.9971 - val_recall_m: 0.9971 - lr: 3.7500e-05
# Epoch 43/50
# 405/404 [==============================] - ETA: 0s - loss: 0.0316 - acc: 0.9880 - f1_m: 0.9883 - precision_m: 0.9900 - recall_m: 0.9867
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.8750000890577212e-05.
#
# Epoch 43: val_f1_m did not improve from 0.99738
# 404/404 [==============================] - 329s 814ms/step - loss: 0.0316 - acc: 0.9880 - f1_m: 0.9883 - precision_m: 0.9900 - recall_m: 0.9867 - val_loss: 0.0058 - val_acc: 0.9969 - val_f1_m: 0.9969 - val_precision_m: 0.9971 - val_recall_m: 0.9968 - lr: 3.7500e-05
# Epoch 43: early stopping
# CPU times: user 8h 33min 54s, sys: 42min 35s, total: 9h 16min 30s
# Wall time: 7h 11min 26s

# %%
history = history_list[0]
print(history.history.keys())
# Out:
# dict_keys(['loss', 'acc', 'f1_m', 'precision_m', 'recall_m', 'val_loss', 'val_acc', 'val_f1_m', 'val_precision_m', 'val_recall_m', 'lr'])

# %%
# save history array to csv and copy the csv file to gdrive/MyDrive

import pandas as pd
import os

# Convert the history object to a pandas DataFrame
df = pd.DataFrame(history.history)

# Save the DataFrame to a CSV file
csv_file_name = 'history.csv'
df.to_csv(csv_file_name, index=False)

# Copy the CSV file to Google Drive
# !cp $csv_file_name "/content/gdrive/MyDrive"

# %% [markdown]
# ### Plotting the Training Scores
#
# 1. Accuracy
# 2. Loss
# 3. F1 Score
# 4. Epoch

# %%
plt.figure(figsize=(7, 7), dpi= 80, facecolor='w', edgecolor='k')
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(7, 7), dpi= 80, facecolor='w', edgecolor='k')
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(7, 7), dpi= 80, facecolor='w', edgecolor='k')
plt.plot(history.history['f1_m'])
plt.plot(history.history['val_f1_m'])
plt.title('model f1_score')
plt.ylabel('f1_score')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# get learning rate graph
def plot_learning_rate(history):
    plt.plot(history.history['lr'])
    plt.xlabel("Epochs")
    plt.ylabel("Learning Rate")
    plt.title("Learning Rate vs Epochs")
    plt.show()


plot_learning_rate(history)

# %%
test_generator = test_datagen.flow_from_dataframe(
    dataframe=df_test,
    directory=TEST_CROPPED_PATH,
    x_col='fname',
    y_col=None,
    target_size= (IMAGE_SIZE, IMAGE_SIZE),
    color_mode='rgb',
    class_mode=None,
    batch_size=BATCH_SIZE,
    shuffle=False
)
# Out:
# Found 3237 validated image filenames.

# %% [markdown]
# ### Predicting the test data images

# %%
prediction = []
for i, name in enumerate(model_names):
    model = get_model(BASE_MODEL, IMAGE_SIZE)
    model.load_weights(name)

    preds = []
    for j in range(TTA_STEPS):
        test_generator.reset()
        pred = model.predict_generator(
            generator=test_generator,
            steps = len(df_test)/BATCH_SIZE,
            verbose=1
        )
        preds.append(pred)
    pred_tta = np.mean(preds, axis=0)

    prediction.append(pred_tta)

y_pred = np.mean(prediction, axis=0)
# Out:
# 101/101 [==============================] - 77s 753ms/step
# 101/101 [==============================] - 75s 736ms/step
# 101/101 [==============================] - 73s 726ms/step
# 101/101 [==============================] - 75s 738ms/step
# 101/101 [==============================] - 75s 738ms/step
# 101/101 [==============================] - 76s 743ms/step
# 101/101 [==============================] - 75s 740ms/step
# 101/101 [==============================] - 74s 727ms/step
# 101/101 [==============================] - 74s 735ms/step
# 101/101 [==============================] - 75s 739ms/step

# %%
preds_class_indices=np.argmax(y_pred, axis=1)

# %%
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
final_pred = [labels[k] for k in preds_class_indices]

# %%
# !cp /content/DataSet/data/test.csv /content/stanford_cars_final_results.csv

# %% [markdown]
# # Saving all the predicted images to the CSV file to plot the test data images

# %%
final_result = pd.read_csv(os.path.join(DATA_PATH, '../stanford_cars_final_results.csv'))
final_result["predicted_class"] = final_pred
final_result.to_csv("stanford_cars_final_results.csv", index=False)
final_result.head(10)
# Out:
#    Unnamed: 0   x1   y1    x2    y2  class      fname predicted_class
# 0           0   30   52   246   147    181  00001.jpg             181
# 1           1  100   19   576   203    103  00002.jpg             103
# 2           2   51  105   968   659    145  00003.jpg             145
# 3           3   67   84   581   407    187  00004.jpg             187
# 4           4  140  151   593   339    185  00005.jpg             185
# 5           5   20   77   420   301     78  00006.jpg              78
# 6           6  249  166  2324  1459    118  00007.jpg             118
# 7           7  119  215  1153   719    165  00008.jpg             165
# 8           8    1    7   275   183     32  00009.jpg              32
# 9           9   28   55   241   177     60  00010.jpg              60

# %% [markdown]
# ### Let's Plot some images based on the predicted values by our model
#
# > Plotting images - test data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import cv2

# Read the final_result.csv file
final_result = pd.read_csv("/content/stanford_cars_final_results.csv")

# Get a random sample of 10 images
images = final_result.sample(n=12)

# Read the class.csv file
# class_dfa = pd.read_csv("/content/class.csv")

# Create a figure with a 2x5 grid of subplots
fig, axes = plt.subplots(3, 4, figsize=(30, 15))

# Iterate through the images and display them
for idx, row in enumerate(images.iterrows()):
    # row[0] is the index, row[1] is the data
    image_file = row[1]["fname"]
    print(row[1]["fname"])
    print(row[1]["class"])

    # Read the image
    image_path = os.path.join("/content/DataSet/images/cars_test/", image_file)
    image = cv2.imread(image_path)

    # Convert color from BGR to RGB (since cv2 reads images in BGR)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Get the class name
    index = row[1]["predicted_class"]
    class_name = df_class["class_name"].iloc[index]  # Adjusted to index without +1 assuming zero-based indexing in class_dfa
    print("class_name: ", class_name)

    # original class name
    original_class_name = df_class["class_name"].iloc[row[1]["class"]]  # Adjusted to index without +1 assuming zero-based indexing in class_dfa
    print("original_class_name: ", original_class_name)

    # Display the image
    ax = axes[idx // 4, idx % 4]  # Use idx which is 0-9 for subplots
    ax.imshow(image)
    ax.set_title(f"Predicted class: {class_name} \n Original Class: {original_class_name}")
    ax.axis("off")

# Show the plot
plt.show()
# Out:
# 00795.jpg
# 116
# class_name:  Ford Fiesta Sedan 2012
# original_class_name:  Ford Fiesta Sedan 2012
# 00247.jpg
# 182
# class_name:  Suzuki SX4 Hatchback 2012
# original_class_name:  Suzuki SX4 Hatchback 2012
# 02875.jpg
# 109
# class_name:  Ford Edge SUV 2012
# original_class_name:  Ford Edge SUV 2012
# 00364.jpg
# 171
# class_name:  Plymouth Neon Coupe 1999
# original_class_name:  Plymouth Neon Coupe 1999
# 00531.jpg
# 108
# class_name:  Ford Expedition EL SUV 2009
# original_class_name:  Ford Expedition EL SUV 2009
# 00963.jpg
# 53
# class_name:  Chevrolet Silverado 1500 Hybrid Crew Cab 2012
# original_class_name:  Chevrolet Silverado 1500 Hybrid Crew Cab 2012
# 02454.jpg
# 169
# class_name:  Nissan Juke Hatchback 2012
# original_class_name:  Nissan Juke Hatchback 2012
# 01248.jpg
# 65
# class_name:  Chevrolet Cobalt SS 2010
# original_class_name:  Chevrolet Cobalt SS 2010
# 01329.jpg
# 119
# class_name:  Chevrolet Monte Carlo Coupe 2007
# original_class_name:  GMC Yukon Hybrid SUV 2012
# 01190.jpg
# 143
# class_name:  Jaguar XK XKR 2012
# original_class_name:  Jaguar XK XKR 2012
# 00413.jpg
# 74
# class_name:  Chevrolet Silverado 1500 Regular Cab 2012
# original_class_name:  Chevrolet Silverado 1500 Regular Cab 2012
# 00639.jpg
# 173
# class_name:  Ram C/V Cargo Van Minivan 2012
# original_class_name:  Ram C/V Cargo Van Minivan 2012

# %%
import datetime

now = datetime.datetime.now()

time = now.strftime("%m-%d-%Y-%H:%M")
date_time = now.strftime("%Y-%m-%d:%H-%M")

print("Time:", time)
print("Date and Time:", date_time)
# Out:
# Time: 04-22-2024-01:39
# Date and Time: 2024-04-22:01-39

# %% [markdown]
# ### Saving the Model to Google Drive

# %%
current_time_str = date_time.replace(":", "at")
# !mkdir /content/gdrive/MyDrive/BigDataAnalyticsProject/Models/{current_time_str}
# !cp /content/*_Xception* /content/gdrive/MyDrive/BigDataAnalyticsProject/Models/{current_time_str}/

# %% [markdown]
# Check the number of class mismatches in test data set after predicting the results from the Xception Model

# %%
import pandas as pd

# Read the final_result.csv file
final_result = pd.read_csv("/content/stanford_cars_final_results.csv")

# Select rows where "class" and "predicted_class" columns are different
mismatches = final_result[final_result["class"] != final_result["predicted_class"]]

# Print the "fname" column of the mismatched rows
print(mismatches["fname"])
print(len(mismatches), " images are mismatched out of ", len(final_result), " in test dataset")
# Out:
# 32      00033.jpg
# 37      00038.jpg
# 64      00065.jpg
# 69      00070.jpg
# 81      00082.jpg
#           ...
# 3158    03159.jpg
# 3163    03164.jpg
# 3214    03215.jpg
# 3223    03224.jpg
# 3230    03231.jpg
# Name: fname, Length: 174, dtype: object
# 174  images are mismatched out of  3237  in test dataset
